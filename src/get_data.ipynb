# %% [markdown]
# # WEB SCRAPING DATA

# %%
#Import the necessary libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import json

# %%
# Web scraping required data from our website and storing it in a csv file using the get_csv function
def get_csv(url, year, fname, cols, table_idx=0):
    response = requests.get(url)
    df = []
    if response.status_code == 200:
    # Parse the HTML content of the page
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find all tables with ID 'btable'
        tables = soup.find_all('table', {'id': 'btable'})

        # Check if there are tables
        if tables:
            # Assume the 'Premier League' table is the first 'btable'
            premier_league_table = tables[table_idx]

            # Extract data from the table
            rows = premier_league_table.find_all('tr')

            # Print the header
            header = [th.text.strip() for th in rows[0].find_all(['th', 'td'])]

            # Print the data
            for row in rows[1:]:
                data = [td.text.strip() for td in row.find_all(['th', 'td'])]
                if len(data) > 0:
                    df.append(data)                    
            df = pd.DataFrame(df, columns=cols)
            df.to_csv(f'../data/raw/{fname}_{year}.csv')
            display(df)
            return df
        else:
            print("No tables with ID 'btable' found on the page.")
    else:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")

# %%
for d in [("", '2023'), ("_2023", '2022'), ("_2022", '2021')]:
    get_csv(f"https://www.soccerstats.com/results.asp?league=england{d[0]}&pmtype=bydate", d[1], "all_matches", cols=['date', 'home_team', 'score', 'away_team', 'stats', 'half_time', '2.5+', 'total_goals', 'btts'])
# Out:
#           date        home_team  score        away_team  stats half_time  \
# 0                          None   None             None   None      None
# 1    Fr 11 Aug          Burnley  0 - 3  Manchester City  stats     (0-2)
# 2                          None   None             None   None      None
# 3    Sa 12 Aug          Arsenal  2 - 1     Nottm Forest  stats     (2-0)
# 4    Sa 12 Aug      Bournemouth  1 - 1     West Ham Utd  stats     (0-0)
# ..         ...              ...    ...              ...    ...       ...
# 460  Su 19 May   Crystal Palace  15:00      Aston Villa    h2h
# 461  Su 19 May        Liverpool  15:00    Wolverhampton    h2h
# 462  Su 19 May       Luton Town  15:00           Fulham    h2h
# 463  Su 19 May  Manchester City  15:00     West Ham Utd    h2h
# 464  Su 19 May    Sheffield Utd  15:00        Tottenham    h2h
#
#      2.5+ total_goals  btts
# 0    None        None  None
# 1       +           3     -
# 2    None        None  None
# 3       +           3     +
# 4       -           2     +
# ..    ...         ...   ...
# 460              None  None
# 461              None  None
# 462              None  None
# 463              None  None
# 464              None  None
#
# [465 rows x 9 columns]
#           date       home_team  score     away_team  stats half_time  2.5+  \
# 0                         None   None          None   None      None  None
# 1     Fr 5 Aug  Crystal Palace  0 - 2       Arsenal  stats     (0-1)     -
# 2                         None   None          None   None      None  None
# 3     Sa 6 Aug          Fulham  2 - 2     Liverpool  stats     (1-0)     +
# 4     Sa 6 Aug     Bournemouth  2 - 0   Aston Villa  stats     (1-0)     -
# ..         ...             ...    ...           ...    ...       ...   ...
# 492  Su 28 May         Everton  1 - 0   Bournemouth  stats     (0-0)     -
# 493  Su 28 May       Leeds Utd  1 - 4     Tottenham  stats     (0-1)     +
# 494  Su 28 May  Leicester City  2 - 1  West Ham Utd  stats     (1-0)     +
# 495  Su 28 May  Manchester Utd  2 - 1        Fulham  stats     (1-1)     +
# 496  Su 28 May     Southampton  4 - 4     Liverpool  stats     (2-2)     +
#
#     total_goals  btts
# 0          None  None
# 1             2     -
# 2          None  None
# 3             4     +
# 4             2     -
# ..          ...   ...
# 492           1     -
# 493           5     +
# 494           3     +
# 495           3     +
# 496           8     +
#
# [497 rows x 9 columns]
#           date        home_team  score       away_team  stats half_time  2.5+  \
# 0                          None   None            None   None      None  None
# 1    Fr 13 Aug        Brentford  2 - 0         Arsenal  stats     (1-0)     -
# 2                          None   None            None   None      None  None
# 3    Sa 14 Aug   Manchester Utd  5 - 1       Leeds Utd  stats     (1-0)     +
# 4    Sa 14 Aug          Burnley  1 - 2        Brighton  stats     (1-0)     +
# ..         ...              ...    ...             ...    ...       ...   ...
# 498  Su 22 May   Crystal Palace  1 - 0  Manchester Utd  stats     (1-0)     -
# 499  Su 22 May   Leicester City  4 - 1     Southampton  stats     (0-0)     +
# 500  Su 22 May        Liverpool  3 - 1   Wolverhampton  stats     (1-1)     +
# 501  Su 22 May  Manchester City  3 - 2     Aston Villa  stats     (0-1)     +
# 502  Su 22 May     Norwich City  0 - 5       Tottenham  stats     (0-2)     +
#
#     total_goals  btts
# 0          None  None
# 1             2     -
# 2          None  None
# 3             6     +
# 4             3     +
# ..          ...   ...
# 498           1     -
# 499           5     +
# 500           4     +
# 501           5     +
# 502           5     -
#
# [503 rows x 9 columns]

# %%
res = []
for d in [("", '2023'), ("_2023", '2022'), ("_2022", '2021')]:
    res = get_csv(f"https://www.soccerstats.com/homeaway.asp?league=england{d[0]}", d[1], "home", cols=["No", "Name", "GP", "W", "D", "L", "GF", "GA", "GD", "Pts"])
# Out:
#     No             Name GP  W  D  L  GF  GA   GD Pts
# 0    1        Liverpool  7  7  0  0  21   5  +16  21
# 1    2    Newcastle Utd  8  7  0  1  19   4  +15  21
# 2    3          Arsenal  8  6  2  0  20   8  +12  20
# 3    4      Aston Villa  6  6  0  0  23   5  +18  18
# 4    5  Manchester City  7  5  2  0  20   7  +13  17
# 5    6         Brighton  7  3  3  1  15  10   +5  12
# 6    7        Brentford  8  3  3  2  15  12   +3  12
# 7    8        Tottenham  6  4  0  2  10   8   +2  12
# 8    9   Manchester Utd  7  4  0  3   8  10   -2  12
# 9   10     West Ham Utd  7  3  2  2  12  10   +2  11
# 10  11     Nottm Forest  7  2  3  2  10   9   +1   9
# 11  12          Chelsea  8  2  3  3  13  13    0   9
# 12  13           Fulham  6  3  0  3   7   9   -2   9
# 13  14      Bournemouth  8  2  3  3   8  12   -4   9
# 14  15    Wolverhampton  6  2  2  2   9  12   -3   8
# 15  16   Crystal Palace  6  1  2  3   6   8   -2   5
# 16  17       Luton Town  6  1  2  3   6   8   -2   5
# 17  18          Everton  7  1  1  5   5   9   -4   4
# 18  19    Sheffield Utd  7  1  1  5   7  19  -12   4
# 19  20          Burnley  8  1  0  7  10  20  -10   3
#     No             Name  GP   W  D   L  GF  GA   GD Pts
# 0    1  Manchester City  19  17  1   1  60  17  +43  52
# 1    2   Manchester Utd  19  15  3   1  36  10  +26  48
# 2    3          Arsenal  19  14  3   2  53  25  +28  45
# 3    4        Liverpool  19  13  5   1  46  17  +29  44
# 4    5    Newcastle Utd  19  11  6   2  36  14  +22  39
# 5    6      Aston Villa  19  12  2   5  33  21  +12  38
# 6    7        Brentford  19  10  7   2  35  18  +17  37
# 7    8        Tottenham  19  12  1   6  37  25  +12  37
# 8    9         Brighton  19  10  4   5  37  21  +16  34
# 9   10     Nottm Forest  19   8  6   5  27  24   +3  30
# 10  11    Wolverhampton  19   9  3   7  19  20   -1  30
# 11  12           Fulham  19   8  5   6  31  29   +2  29
# 12  13     West Ham Utd  19   8  4   7  26  24   +2  28
# 13  14   Crystal Palace  19   7  7   5  21  23   -2  28
# 14  15          Chelsea  19   6  7   6  20  19   +1  25
# 15  16      Bournemouth  19   6  4   9  20  28   -8  22
# 16  17        Leeds Utd  19   5  7   7  26  37  -11  22
# 17  18          Everton  19   6  3  10  16  27  -11  21
# 18  19   Leicester City  19   5  4  10  23  27   -4  19
# 19  20      Southampton  19   2  5  12  19  37  -18  11
#     No             Name  GP   W  D   L  GF  GA   GD Pts
# 0    1        Liverpool  19  15  4   0  49   9  +40  49
# 1    2  Manchester City  19  15  2   2  58  15  +43  47
# 2    3          Arsenal  19  13  2   4  35  17  +18  41
# 3    4        Tottenham  19  13  1   5  38  19  +19  40
# 4    5   Manchester Utd  19  10  5   4  32  22  +10  35
# 5    6          Chelsea  19   9  7   3  37  22  +15  34
# 6    7   Leicester City  19  10  4   5  34  23  +11  34
# 7    8     West Ham Utd  19   9  5   5  33  26   +7  32
# 8    9    Newcastle Utd  19   8  6   5  26  27   -1  30
# 9   10   Crystal Palace  19   7  8   4  27  17  +10  29
# 10  11          Everton  19   9  2   8  27  25   +2  29
# 11  12      Southampton  19   6  7   6  23  24   -1  25
# 12  13        Brentford  19   7  3   9  22  21   +1  24
# 13  14    Wolverhampton  19   7  3   9  20  25   -5  24
# 14  15      Aston Villa  19   6  5   8  29  29    0  23
# 15  16         Brighton  19   5  7   7  19  23   -4  22
# 16  17          Burnley  19   5  6   8  18  25   -7  21
# 17  18        Leeds Utd  19   4  6   9  19  38  -19  18
# 18  19     Norwich City  19   3  3  13  12  43  -31  12
# 19  20          Watford  19   2  2  15  17  46  -29   8

# %%
for d in [("", '2023'), ("_2023", '2022'), ("_2022", '2021')]:
    get_csv(f"https://www.soccerstats.com/homeaway.asp?league=england{d[0]}&stats=8", d[1], "away", cols=["No", "Name", "GP", "W", "D", "L", "GF", "GA", "GD", "Pts"], table_idx=1)
# Out:
#     No             Name GP  W  D  L  GF  GA   GD Pts
# 0    1        Tottenham  8  4  3  1  18  12   +6  15
# 1    2  Manchester City  7  4  1  2  16   9   +7  13
# 2    3          Arsenal  6  4  1  1   9   3   +6  13
# 3    4          Everton  7  4  1  2  10  11   -1  13
# 4    5   Manchester Utd  7  4  0  3   8   7   +1  12
# 5    6   Crystal Palace  8  3  2  3   8  11   -3  11
# 6    7      Aston Villa  8  3  2  3  10  15   -5  11
# 7    8          Chelsea  6  3  1  2  12   9   +3  10
# 8    9        Liverpool  7  2  4  1  11   9   +2  10
# 9   10         Brighton  7  3  1  3  15  16   -1  10
# 10  11     West Ham Utd  7  3  1  3  12  14   -2  10
# 11  12        Brentford  6  2  1  3   7   7    0   7
# 12  13    Wolverhampton  8  2  1  5  10  13   -3   7
# 13  14           Fulham  8  1  3  4   9  17   -8   6
# 14  15    Newcastle Utd  6  1  2  3  13  10   +3   5
# 15  16     Nottm Forest  7  1  1  5   6  13   -7   4
# 16  17          Burnley  6  1  1  4   5  12   -7   4
# 17  18      Bournemouth  6  1  1  4   8  18  -10   4
# 18  19       Luton Town  8  1  1  6   7  18  -11   4
# 19  20    Sheffield Utd  7  0  1  6   4  20  -16   1
#     No             Name  GP   W  D   L  GF  GA   GD Pts
# 0    1          Arsenal  19  12  3   4  35  18  +17  39
# 1    2  Manchester City  19  11  4   4  34  16  +18  37
# 2    3    Newcastle Utd  19   8  8   3  32  19  +13  32
# 3    4         Brighton  19   8  4   7  35  32   +3  28
# 4    5   Manchester Utd  19   8  3   8  22  33  -11  27
# 5    6           Fulham  19   7  2  10  24  24    0  23
# 6    7        Liverpool  19   6  5   8  29  30   -1  23
# 7    8        Tottenham  19   6  5   8  33  38   -5  23
# 8    9      Aston Villa  19   6  5   8  18  25   -7  23
# 9   10        Brentford  19   5  7   7  23  28   -5  22
# 10  11          Chelsea  19   5  4  10  18  28  -10  19
# 11  12   Crystal Palace  19   4  5  10  19  26   -7  17
# 12  13      Bournemouth  19   5  2  12  17  43  -26  17
# 13  14          Everton  19   2  9   8  18  30  -12  15
# 14  15   Leicester City  19   4  3  12  28  41  -13  15
# 15  16      Southampton  19   4  2  13  17  36  -19  14
# 16  17     West Ham Utd  19   3  3  13  16  31  -15  12
# 17  18    Wolverhampton  19   2  5  12  12  38  -26  11
# 18  19        Leeds Utd  19   2  3  14  22  41  -19   9
# 19  20     Nottm Forest  19   1  5  13  11  44  -33   8
#     No             Name  GP   W  D   L  GF  GA   GD Pts
# 0    1  Manchester City  19  14  4   1  41  11  +30  46
# 1    2        Liverpool  19  13  4   2  45  17  +28  43
# 2    3          Chelsea  19  12  4   3  39  11  +28  40
# 3    4        Tottenham  19   9  4   6  31  21  +10  31
# 4    5         Brighton  19   7  8   4  23  21   +2  29
# 5    6          Arsenal  19   9  1   9  26  31   -5  28
# 6    7    Wolverhampton  19   8  3   8  18  18    0  27
# 7    8     West Ham Utd  19   7  3   9  27  25   +2  24
# 8    9   Manchester Utd  19   6  5   8  25  35  -10  23
# 9   10      Aston Villa  19   7  1  11  23  25   -2  22
# 10  11        Brentford  19   6  4   9  26  35   -9  22
# 11  12        Leeds Utd  19   5  5   9  23  41  -18  20
# 12  13   Crystal Palace  19   4  7   8  23  29   -6  19
# 13  14    Newcastle Utd  19   5  4  10  18  35  -17  19
# 14  15   Leicester City  19   4  6   9  28  36   -8  18
# 15  16          Watford  19   4  3  12  17  31  -14  15
# 16  17      Southampton  19   3  6  10  20  43  -23  15
# 17  18          Burnley  19   2  8   9  16  28  -12  14
# 18  19          Everton  19   2  4  13  16  41  -25  10
# 19  20     Norwich City  19   2  4  13  11  41  -30  10
